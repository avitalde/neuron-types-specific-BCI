# %% [markdown]
# # Dataset C15
# Only when computed with 2,3,4 clusters interval is correct

# %% [markdown]
# ## Cluster properties

# %% [markdown]
# ### Number of neurons per cluster

# %%
# 4 Clusters (Louvain)
neurons_per_cluster = [78, 112, 26, 93]

# 4 Clusters (KMeans)
neurons_per_cluster = [71, 86, 69, 83]

# 3 Clusters
neurons_per_cluster = [107, 109, 93]

# %% [markdown]
# ### PCA

# %%
# 7 Clusters
PCA_dims = 11 # to get 85% explained variance in smallest cluster

# 6 Clusters
PCA_dims = 11 # to get 85% explained variance in smallest cluster

# 4 Clusters (Louvain)
PCA_dims = [34, 65, 10, 55] # to get 85% explained variance in each cluster

# 4 Clusters - correct interval (movement)
PCA_dims = [31, 63, 10, 52] # to get 85% explained variance in each cluster

# 4 Clusters - correct interval (preparation)
PCA_dims = [38, 65, 11, 54] # to get 85% explained variance in each cluster

# 4 Clusters (KMeans)
PCA_dims = 35 # to get 85% explained variance in smallest cluster

# check number of neurons in each cluster and number of PCA to see if more or less it's the same for each one
# 3 Clusters
PCA_dims = [59, 51, 55] # to get 85% explained variance in each cluster

# %% [markdown]
# ### Firing rate

# %%
# 7 Clusters
meanFR = [9.19247286, 9.88086486,  8.24961678, 9.21948816, 12.45212654, 7.28456179, 6.89928459]
smeFR = [0.93810989, 1.10757055, 1.01245105, 0.79958562, 2.31149547, 0.62114394, 1.61991515]
FR_overall_mean = 8.828897037498102
FR_overall_sme = 0.4117036533753934
maxFR = [39.78979501, 34.37300123, 28.20694686, 21.46998094, 44.57379426, 27.19000228, 29.4205603]

# 6 Clusters
meanFR = [9.38224026, 9.21948816, 8.30469846, 12.45212654, 7.19342094, 9.46311428]
smeFR = [1.01996745, 0.79958562, 1.0350576, 2.31149547, 0.60992364, 0.98452253]
FR_overall_mean = 8.828897037498102
FR_overall_sme = 0.4117036533753934
maxFR = [34.37300123, 21.46998094, 28.20694686, 44.57379426, 29.4205603, 39.78979501]

# 4 CLusters (Louvain) - movement
meanFR = [9.94620852, 9.50420066, 12.07152754, 7.29593896]
smeFR = [0.98918425, 0.66722433, 2.52295851, 0.65064791]
FR_overall_mean = 9.16717403829644
FR_overall_sme = 0.45889708427202486
maxFR = [39.24957606, 40.20934747, 42.91737708, 31.99942679]

# 4 CLusters (Louvain) - preparation
meanFR = [ 9.4499789, 9.71128836, 13.94828145, 7.22971221]
smeFR = [0.79124121, 0.64868033, 2.32780558, 0.61102188]
FR_overall_mean = 9.254955353279467
FR_overall_sme = 0.4214564939743875
maxFR = [34.84928113, 40.68699181, 48.79190428, 29.38163385]

# 4 CLusters (KMeans)
meanFR = [ 8.95662302, 6.7116695, 10.87093146, 9.21579641]
smeFR = [0.86599933, 0.58601789, 1.03830978, 0.76617395]
FR_overall_mean = 8.828897037498102
FR_overall_sme = 0.4117036533753934
maxFR = [39.78979501, 29.4205603, 44.57379426, 34.37300123]

# 3 Clusters - movement
meanFR = [10.57263398, 9.38406073, 7.29593896]
smeFR = [0.81520125, 0.83556407, 0.65064791]
FR_overall_mean = 9.16717403829644
FR_overall_sme = 0.45889708427202486
maxFR = [40.20934747, 42.91737708, 31.99942679]

# 2 Clusters - movement
meanFR = [9.9728447, 7.29593896]
smeFR = [0.58523488, 0.65064791]
FR_overall_mean = 9.16717403829644
FR_overall_sme = 0.45889708427202486
maxFR = [42.91737708, 31.99942679]

# %% [markdown]
# ### Peak to Trough

# %%
# 7 Clusters
meanPTT = [0.24375, 0.15804878048780488, 0.2141860465116279, 0.30642857142857144, 0.2526923076923077, 0.5083098591549295, 0.4977272727272727]
smePTT = [0.013332621237494898, 0.004965311104041651, 0.00989524667582896, 0.008721057923896236, 0.008661239445373075, 0.015729293344992616, 0.014770025181995607]
PTT_overall_mean = 0.3164077669902913
PTT_overall_sme = 0.009010090372780237

# 6 Clusters
meanPTT = [0.1597826086956522, 0.30642857142857144, 0.21285714285714286, 0.2526923076923077, 0.5058064516129032, 0.24999999999999997]
smePTT = [0.005139721977604265, 0.008721057923896236, 0.010041217291922115, 0.008661239445373075, 0.012515059796774829, 0.013832329280830951]
PTT_overall_mean = 0.3164077669902913
PTT_overall_sme = 0.009010090372780237

# 4 Clusters (Louvain)
meanPTT = [0.18807692307692309, 0.2633035714285714, 0.2526923076923077, 0.5058064516129032]
smePTT = [0.006829995558296806, 0.009017758479708805, 0.008661239445373075, 0.012515059796774829]
PTT_overall_mean = 0.3164077669902913
PTT_overall_sme = 0.009010090372780237

# 4 Clusters (KMeans)
meanPTT = [0.24676056338028157, 0.5145348837209301, 0.29826086956521736, 0.18578313253012047]
smePTT = [0.012072936198381956, 0.013047793512392344, 0.008108061706679652, 0.006434503094632526]
PTT_overall_mean = 0.3164077669902913
PTT_overall_sme = 0.009010090372780237

# 3 Clusters
meanPTT = [0.2116822429906542, 0.2576146788990825, 0.5058064516129032]
smePTT = [0.009195507511538801, 0.006755308315040605, 0.012515059796774829]
PTT_overall_mean = 0.3164077669902913
PTT_overall_sme = 0.009010090372780237

# 2 Clusters
meanPTT = [0.23486111111111113, 0.5058064516129032]
smePTT = [0.005900182496518797, 0.012515059796774829]
PTT_overall_mean = 0.3164077669902913
PTT_overall_sme = 0.009010090372780237

# %% [markdown]
# ### AP width

# %%
# 4 Clusters (Louvain)
meanAP = [0.11615384615384612, 0.12910714285714286, 0.14423076923076922, 0.16677419354838707]
smeAP = [0.0026845478478927406, 0.001998698442193816, 0.0028353786115319444, 0.00211345058615138]
AP_overall_mean = 0.13844660194174754
AP_overall_sme = 0.0016566746348767706

# 3 Clusters
meanAP = [0.11719626168224297, 0.13513761467889907, 0.16677419354838707]
smeAP = [0.0017069544931761378, 0.00235554698835043, 0.00211345058615138]
AP_overall_mean = 0.13844660194174754
AP_overall_sme = 0.0016566746348767706

# 2 Clusters
meanAP = [0.12625, 0.16677419354838707]
smeAP = [0.0015812913245466247, 0.00211345058615138]
AP_overall_mean = 0.13844660194174754
AP_overall_sme = 0.0016566746348767706

# %% [markdown]
# ## R2 for Velocity decoding (LSTM)

# %%
# 7 Clusters
# R2 from each cluster
r2 = [[ 0.07920876,  0.46208026,  0.67591469,  0.4918369 ,  0.80538281, 0.08413454,  0.43445719],
       [ 0.18427756,  0.48410782,  0.49963353,  0.49040465,  0.73836657, 0.275845  ,  0.43073448],
       [ 0.2067358 ,  0.46917811,  0.58147911,  0.36479807,  0.7958193 , 0.01254984,  0.41825234],
       [ 0.26820713,  0.44064239,  0.55134279,  0.61879927,  0.79523468, -0.04589933,  0.41578136],
       [ 0.12921996,  0.41291937,  0.59606553,  0.31453832,  0.78301668, 0.1932742 ,  0.40863433],
       [ 0.12750339,  0.39381416,  0.58687323,  0.61324488,  0.76042693, 0.21168366,  0.43786926],
       [-0.10651859,  0.57792476,  0.54981287,  0.39671775,  0.75680701, 0.24348573,  0.38431064],
       [ 0.26514642,  0.44160587,  0.5989922 ,  0.45708818,  0.76377301, 0.32467316,  0.4477635 ],
       [ 0.09150758,  0.45421706,  0.52676518,  0.50222863,  0.74898369, 0.07005626,  0.43650614],
       [ 0.02325768,  0.34740517,  0.49912921,  0.5250197 ,  0.78059907, 0.35305238,  0.39993906]]

# R2 sampling neurons randomly from dataset
r2_all = [0.47592182, 0.08039866, 0.47882739, 0.33706167, 0.57415099,
          0.52489127, 0.70697434, 0.18824384, 0.27040499, 0.22888387]

# %%
# 6 Clusters
# R2 from each cluster
r2 = [[0.46354002, 0.43064355, 0.60994753, 0.78451289, 0.0178557 , 0.21423315],
      [0.38530271, 0.51913803, 0.62107592, 0.76569418, 0.36210527, 0.3118739 ],
      [0.30362949, 0.40641969, 0.58742367, 0.75805063, 0.3433923 , 0.1484435 ],
      [0.38026645, 0.35980499, 0.54427834, 0.75234119, 0.27774643, 0.13585311],
      [0.40023574, 0.31305352, 0.68162855, 0.76566676, 0.04780561, 0.20729708],
      [0.3610498 , 0.52328373, 0.70445512, 0.7431514 , 0.29727539, 0.3162367 ],
      [0.30228921, 0.54174997, 0.71313922, 0.71702637, 0.1814295 , -0.03044723],
      [0.37522713, 0.41458004, 0.55112703, 0.75083213 , 0.48292389, 0.28928828],
      [0.41234994, 0.4451115 , 0.64755027, 0.7410602 , 0.33643103, 0.17768944],
      [0.23162071, 0.54394914, 0.64255285, 0.76995886, 0.37851058, 0.18916347]]

# R2 sampling neurons randomly from dataset
r2_all = [0.35195263, 0.36315046, 0.55786649, 0.27820033, 0.41453512,
          0.05909951, 0.53303093, 0.43532638, 0.34515934, 0.41672715]

# %%
# 4 Clusters - correct time interval
# R2 from each cluster
r2 = [[0.63994349, 0.46589519, 0.78985291, 0.32735527],
       [0.53224264, 0.59064838, 0.83182818, 0.35468134],
       [0.57242827, 0.43057465, 0.80386477, 0.37617638],
       [0.59577081, 0.49352042, 0.77453301, 0.19667977],
       [0.42277219, 0.49280916, 0.7866612 , 0.22538931],
       [0.720604  , 0.44298391, 0.79065708, 0.28753639],
       [0.58793932, 0.52107392, 0.83152045, 0.21090016],
       [0.49437553, 0.38772157, 0.81361851, 0.23883884],
       [0.59520976, 0.45914476, 0.76801187, 0.4703851 ],
       [0.57928957, 0.47613331, 0.80772653, 0.33780087]]

# R2 sampling neurons randomly from dataset
r2_all = [0.53831322, 0.33053411, 0.50809464, 0.42552568, 0.2248439 ,
           0.44557115, 0.63009945, 0.55443422, 0.64266823, 0.35720269,
           0.54363498, 0.51663147]

# %%
# 3 Clusters
# N_samples=15, pca_dims=10
# R2 from each cluster
r2 = [[ 0.17316956,  0.37843148,  0.46609899],
       [ 0.2812594 ,  0.50950697,  0.30179795],
       [ 0.05160788,  0.70066538, -0.0675997 ],
       [ 0.23643021,  0.54587905,  0.19072256],
       [ 0.34101762,  0.40186539,  0.24007924],
       [ 0.33528472,  0.69065958,  0.18140868],
       [ 0.31071091,  0.67315274,  0.20012948],
       [ 0.14217633,  0.7472736 ,  0.15287723],
       [ 0.24264078,  0.72931081,  0.40711897],
       [ 0.13154429,  0.50713863,  0.44536091]]

# R2 sampling neurons randomly from dataset
r2_all = [0.58716387, 0.52232019, 0.40582172, 0.08812219, 0.58968428, 0.24115148, 
          0.53426909, 0.19525395, 0.66885282, 0.29370897, 0.51296888, 0.26433296,
          0.5992474 , 0.28792208, 0.14337962, 0.40554729, 0.48714295, 0.37319537,
          0.15294397, 0.31662469, 0.08408622, 0.23086692, 0.31644881, 0.52594739,
          0.37288612, 0.25654615, 0.03099208, 0.40314961, 0.37090221, 0.47618264]

# %%
# 2 Clusters
# N_samples=15, pca_dims=10

# R2 from each cluster
r2 = [[ 0.18322046,  0.11186431],
       [ 0.53786857, -0.10085766],
       [ 0.10739923,  0.19689904],
       [ 0.62558468,  0.10697097],
       [ 0.50637202,  0.35574915],
       [-0.00647245,  0.24505045],
       [ 0.27031455,  0.14644502],
       [ 0.45957239,  0.33008156],
       [ 0.40046207,  0.15248901],
       [ 0.38411145,  0.11642515]]

# R2 sampling neurons randomly from dataset
r2_all = [0.41712297, 0.43716471, 0.40054827, 0.41291158, 0.50084183,
          0.65516309, 0.31997274, 0.44597222, 0.4606195 , 0.16654651]

# %% [markdown]
# ## Accuracy for Target classifier (LSTM)

# %%
# 7 Clusters
# acc from each cluster
acc = [[0.54255319, 0.69148936, 0.79787234, 0.75531915, 0.78723404, 0.4893617 , 0.77659574],
       [0.60638298, 0.57446809, 0.73404255, 0.55319149, 0.85106383, 0.43617021, 0.77659574],
       [0.62765957, 0.72340426, 0.80851064, 0.59574468, 0.82978723, 0.38297872, 0.75531915],
       [0.64893617, 0.69148936, 0.74468085, 0.72340426, 0.91489362, 0.41489362, 0.77659574],
       [0.5212766 , 0.54255319, 0.69148936, 0.77659574, 0.85106383, 0.29787234, 0.79787234],
       [0.44680851, 0.57446809, 0.55319149, 0.79787234, 0.86170213, 0.4787234 , 0.64893617],
       [0.39361702, 0.65957447, 0.85106383, 0.60638298, 0.90425532, 0.55319149, 0.81914894],
       [0.5       , 0.60638298, 0.76595745, 0.68085106, 0.77659574, 0.5       , 0.71276596],
       [0.45744681, 0.61702128, 0.81914894, 0.67021277, 0.81914894, 0.54255319, 0.79787234],
       [0.58510638, 0.62765957, 0.55319149, 0.61702128, 0.85106383, 0.5106383 , 0.79787234]]

# acc sampling neurons randomly from dataset
acc_all = [0.68131868, 0.54945055, 0.85714286, 0.72527473, 0.82417582,
           0.73626374, 0.86813187, 0.8021978 , 0.7032967 , 0.72527473]

# %%
# 6 CLusters
# acc from each cluster
acc = [[0.45454545, 0.70909091, 0.69090909, 0.78181818, 0.43636364, 0.43636364],
       [0.67272727, 0.61818182, 0.56363636, 0.78181818, 0.38181818, 0.34545455],
       [0.54545455, 0.47272727, 0.72727273, 0.61818182, 0.43636364, 0.34545455],
       [0.30909091, 0.65454545, 0.83636364, 0.81818182, 0.4       , 0.49090909],
       [0.4       , 0.6       , 0.70909091, 0.78181818, 0.30909091, 0.36363636],
       [0.54545455, 0.67272727, 0.70909091, 0.8       , 0.47272727, 0.43636364],
       [0.70909091, 0.56363636, 0.58181818, 0.72727273, 0.4       , 0.21818182],
       [0.54545455, 0.6       , 0.81818182, 0.69090909, 0.52727273, 0.43636364],
       [0.54545455, 0.45454545, 0.54545455, 0.74545455, 0.54545455, 0.45454545],
       [0.49090909, 0.58181818, 0.61818182, 0.8       , 0.41818182, 0.50909091]]

# acc sampling neurons randomly from dataset
acc_all = [0.50909091, 0.41818182, 0.36363636, 0.49090909, 0.38181818,
           0.36363636, 0.49090909, 0.47272727, 0.50909091, 0.67272727]

# %%
# 4 Clusters - correct interval
# acc from each cluster
acc = [[0.55319149, 0.56382979, 0.80851064, 0.46808511],
       [0.77659574, 0.55319149, 0.76595745, 0.56382979],
       [0.75531915, 0.4787234 , 0.73404255, 0.43617021],
       [0.71276596, 0.56382979, 0.70212766, 0.4787234 ],
       [0.65957447, 0.62765957, 0.73404255, 0.35106383],
       [0.5212766 , 0.5106383 , 0.82978723, 0.41489362],
       [0.60638298, 0.4893617 , 0.80851064, 0.44680851],
       [0.68085106, 0.43617021, 0.80851064, 0.55319149],
       [0.72340426, 0.54255319, 0.80851064, 0.39361702],
       [0.65957447, 0.53191489, 0.73404255, 0.4787234 ]]
# acc sampling neurons randomly from dataset
acc_all = [0.59574468, 0.53191489, 0.62765957, 0.5212766, 0.67021277,
           0.65957447, 0.75531915, 0.4893617, 0.61702128, 0.69148936,
           0.60638298, 0.64893617]

# %%
# 4 Clusters - avg pca
# pca_dims=10, N_samples=15
# acc from each cluster
acc = [[0.71276596, 0.41489362, 0.79787234, 0.46808511],
       [0.67021277, 0.56382979, 0.71276596, 0.34042553],
       [0.61702128, 0.45744681, 0.81914894, 0.45744681],
       [0.62765957, 0.53191489, 0.85106383, 0.5       ],
       [0.67021277, 0.5       , 0.73404255, 0.5       ],
       [0.67021277, 0.5212766 , 0.68085106, 0.38297872],
       [0.46808511, 0.45744681, 0.70212766, 0.34042553],
       [0.65957447, 0.36170213, 0.73404255, 0.44680851],
       [0.59574468, 0.39361702, 0.77659574, 0.5106383 ],
       [0.65957447, 0.35106383, 0.72340426, 0.54255319]]

# acc sampling neurons randomly from dataset
acc_all = [0.57446809, 0.5106383 , 0.39361702, 0.68085106, 0.61702128,
           0.55319149, 0.46808511, 0.69148936,0.55319149, 0.29787234,
           0.37234043, 0.5]

# %%
# 4 Clusters (kMeans)
# acc from each cluster
acc = [[0.4       , 0.34545455, 0.47272727, 0.58181818],
       [0.32727273, 0.50909091, 0.52727273, 0.78181818],
       [0.27272727, 0.4       , 0.70909091, 0.6       ],
       [0.43636364, 0.43636364, 0.49090909, 0.54545455],
       [0.27272727, 0.41818182, 0.54545455, 0.50909091],
       [0.54545455, 0.38181818, 0.58181818, 0.67272727],
       [0.25454545, 0.45454545, 0.67272727, 0.6       ],
       [0.49090909, 0.32727273, 0.8       , 0.65454545],
       [0.45454545, 0.41818182, 0.61818182, 0.54545455],
       [0.2       , 0.50909091, 0.56363636, 0.58181818]]

# acc sampling neurons randomly from dataset
acc_all = [0.63636364, 0.50909091, 0.58181818, 0.56363636, 0.49090909,
           0.49090909, 0.76363636, 0.45454545, 0.41818182, 0.47272727]

# %%
# 3 Clusters
# acc from each cluster
acc = [[0.61818182, 0.69090909, 0.65454545],
       [0.58181818, 0.69090909, 0.63636364],
       [0.63636364, 0.74545455, 0.56363636],
       [0.67272727, 0.69090909, 0.61818182],
       [0.58181818, 0.56363636, 0.54545455],
       [0.58181818, 0.69090909, 0.49090909],
       [0.50909091, 0.87272727, 0.61818182],
       [0.6       , 0.85454545, 0.56363636],
       [0.58181818, 0.81818182, 0.61818182],
       [0.58181818, 0.8       , 0.52727273]]

# acc sampling neurons randomly from dataset
acc_all = [0.6       , 0.72727273, 0.74545455, 0.6       , 0.81818182,
           0.70909091, 0.74545455, 0.69090909, 0.69090909, 0.69090909]

# %%
# 3 Clusters - corrected interval
# acc from each cluster
acc = [[0.71276596, 0.79787234, 0.75531915],
      [0.65957447, 0.79787234, 0.68085106],
       [0.75531915, 0.87234043, 0.67021277],
       [0.56382979, 0.86170213, 0.63829787],
       [0.65957447, 0.87234043, 0.60638298],
       [0.67021277, 0.90425532, 0.70212766],
       [0.62765957, 0.89361702, 0.62765957],
       [0.73404255, 0.79787234, 0.62765957],
       [0.74468085, 0.90425532, 0.61702128],
       [0.59574468, 0.85106383, 0.61702128]]

# acc sampling neurons randomly from dataset
acc_all = [0.76595745, 0.73404255, 0.63829787, 0.86170213, 0.87234043,
           0.71276596, 0.92553191, 0.76595745, 0.79787234, 0.70212766]

# %% [markdown]
# ## Accuracy for Target classifier (GNB)

# %%
# 7 Clusters
# acc from each cluster
accGNB = [[0.77659574, 0.93617021, 0.82978723, 0.61702128, 0.93617021, 0.5       , 0.88297872],
          [0.64893617, 0.92553191, 0.81914894, 0.68085106, 0.96808511, 0.55319149, 0.85106383],
          [0.60638298, 0.92553191, 0.85106383, 0.80851064, 0.92553191, 0.59574468, 0.86170213],
          [0.4893617 , 0.90425532, 0.87234043, 0.85106383, 0.93617021, 0.4893617 , 0.88297872],
          [0.41489362, 0.74468085, 0.88297872, 0.78723404, 0.95744681, 0.46808511, 0.87234043],
          [0.55319149, 0.86170213, 0.91489362, 0.71276596, 0.95744681, 0.45744681, 0.85106383],
          [0.61702128, 0.69148936, 0.90425532, 0.75531915, 0.95744681, 0.56382979, 0.85106383],
          [0.78723404, 0.93617021, 0.87234043, 0.90425532, 0.91489362, 0.67021277, 0.85106383],
          [0.68085106, 0.85106383, 0.89361702, 0.87234043, 0.93617021, 0.58510638, 0.89361702],
          [0.61702128, 0.88297872, 0.85106383, 0.81914894, 0.94680851, 0.69148936, 0.86170213]]

# acc sampling neurons randomly from dataset
acc_allGNB = [0.69148936, 0.85106383, 0.93617021, 0.86170213, 0.93617021,
           0.58510638, 0.86170213, 0.75531915, 0.81914894, 0.91489362]

# %%
# 6 Clusters
# acc from each cluster
accGNB = [[0.79787234, 0.53191489, 0.90425532, 0.93617021, 0.53191489, 0.61702128],
          [0.89361702, 0.54255319, 0.88297872, 0.91489362, 0.65957447, 0.5106383 ],
          [0.71276596, 0.79787234, 0.92553191, 0.90425532, 0.60638298, 0.53191489],
          [0.74468085, 0.72340426, 0.87234043, 0.90425532, 0.4787234 , 0.55319149],
          [0.79787234, 0.81914894, 0.85106383, 0.91489362, 0.64893617, 0.62765957],
          [0.87234043, 0.87234043, 0.94680851, 0.94680851, 0.69148936, 0.5212766 ],
          [0.77659574, 0.84042553, 0.89361702, 0.91489362, 0.44680851, 0.67021277],
          [0.88297872, 0.76595745, 0.88297872, 0.89361702, 0.76595745, 0.61702128],
          [0.73404255, 0.85106383, 0.92553191, 0.94680851, 0.5       , 0.43617021],
          [0.89361702, 0.62765957, 0.86170213, 0.91489362, 0.69148936, 0.61702128]]

# acc sampling neurons randomly from dataset
acc_allGNB = [0.63829787, 0.79787234, 0.84042553, 0.75531915, 0.71276596,
              0.84042553, 0.68085106, 0.77659574, 0.67021277, 0.77659574]

# %%
# 4 Clusters
# acc from each cluster
accGNB = [[0.74468085, 0.61702128, 0.86170213, 0.44680851],
       [0.70212766, 0.44680851, 0.85106383, 0.44680851],
       [0.71276596, 0.65957447, 0.82978723, 0.58510638],
       [0.67021277, 0.64893617, 0.82978723, 0.57446809],
       [0.61702128, 0.57446809, 0.88297872, 0.61702128],
       [0.74468085, 0.59574468, 0.86170213, 0.40425532],
       [0.69148936, 0.5106383 , 0.87234043, 0.54255319],
       [0.62765957, 0.45744681, 0.76595745, 0.4893617 ],
       [0.74468085, 0.4893617 , 0.86170213, 0.54255319],
       [0.75531915, 0.56382979, 0.89361702, 0.5106383 ]]

# acc sampling neurons randomly from dataset
acc_allGNB = [0.5106383 , 0.64893617, 0.64893617, 0.58510638, 0.77659574,
              0.32978723, 0.62765957, 0.67021277, 0.70212766, 0.58510638]

# %%
# 4 Clusters (KMeans)
# acc from each cluster
accGNB = [[0.4       , 0.56363636, 0.81818182, 0.69090909],
          [0.43636364, 0.54545455, 0.74545455, 0.54545455],
          [0.50909091, 0.47272727, 0.78181818, 0.6       ],
          [0.50909091, 0.50909091, 0.8       , 0.63636364],
          [0.58181818, 0.43636364, 0.74545455, 0.50909091],
          [0.49090909, 0.61818182, 0.58181818, 0.6       ],
          [0.2       , 0.45454545, 0.54545455, 0.70909091],
          [0.56363636, 0.6       , 0.85454545, 0.67272727],
          [0.45454545, 0.6       , 0.74545455, 0.69090909],
          [0.47272727, 0.63636364, 0.54545455, 0.65454545]]

# acc sampling neurons randomly from dataset
acc_allGNB = [0.74545455, 0.58181818, 0.61818182, 0.52727273, 0.58181818,
              0.8       , 0.65454545, 0.70909091, 0.70909091, 0.50909091]

# %%
# 3 Clusters
# acc from each cluster
accGNB = [[0.54545455, 0.94545455, 0.6       ],
          [0.49090909, 0.89090909, 0.65454545],
          [0.58181818, 0.87272727, 0.50909091],
          [0.52727273, 0.89090909, 0.61818182],
          [0.52727273, 0.92727273, 0.69090909],
          [0.61818182, 0.92727273, 0.67272727],
          [0.47272727, 0.87272727, 0.56363636],
          [0.56363636, 0.83636364, 0.58181818],
          [0.50909091, 0.90909091, 0.54545455],
          [0.50909091, 0.8       , 0.52727273]]

# acc sampling neurons randomly from dataset
acc_allGNB = [0.67272727, 0.6       , 0.72727273, 0.74545455, 0.74545455,
              0.72727273, 0.76363636, 0.69090909, 0.65454545, 0.52727273]

# %% [markdown]
# ## M1 vs PMd

# %%
# 4 Clusters - movement, correct interval
# pca_dims=10, N_samples = 35
r2 = [[0.71466408, 0.45316856],
       [0.79398711, 0.60870885],
       [0.73613147, 0.5587564 ],
       [0.6595392 , 0.64368682],
       [0.75613845, 0.57960338],
       [0.74589736, 0.52546564],
       [0.79387082, 0.5375093 ],
       [0.76378552, 0.61521015],
       [0.75751748, 0.45806432],
       [0.7852257 , 0.6357287 ]]

# %%
# 4 Clusters - preparation, correct interval
# pca_dims = 10, N_samples = 35
acc = [[0.60638298, 0.78723404],
       [0.74468085, 0.73404255],
       [0.65957447, 0.75531915],
       [0.69148936, 0.65957447],
       [0.72340426, 0.57446809],
       [0.72340426, 0.76595745],
       [0.77659574, 0.58510638],
       [0.57446809, 0.60638298],
       [0.67021277, 0.63829787],
       [0.63829787, 0.46808511]]

# %%
# 4 Clusters - preparation, correct interval
# pca_dims = 25, N_samples = 35
acc = [[0.69148936, 0.71276596],
       [0.69148936, 0.64893617],
       [0.72340426, 0.72340426],
       [0.64893617, 0.57446809],
       [0.73404255, 0.62765957],
       [0.72340426, 0.76595745],
       [0.65957447, 0.67021277],
       [0.58510638, 0.72340426],
       [0.71276596, 0.67021277],
       [0.58510638, 0.68085106]]

# pca_dims = 10, N_samples = 15
acc = [[0.73404255, 0.55319149],
       [0.64893617, 0.56382979],
       [0.62765957, 0.58510638],
       [0.54255319, 0.64893617],
       [0.71276596, 0.46808511],
       [0.57446809, 0.63829787],
       [0.4893617 , 0.45744681],
       [0.5106383 , 0.43617021],
       [0.65957447, 0.40425532],
       [0.67021277, 0.43617021]]

# pca_dims = 10, N_samples = 55
acc = [0.79787234, 0.63829787],
       [0.73404255, 0.65957447],
       [0.65957447, 0.78723404],
       [0.71276596, 0.70212766],
       [0.79787234, 0.74468085],
       [0.71276596, 0.74468085],
       [0.74468085, 0.75531915],
       [0.71276596, 0.75531915],
       [0.86170213, 0.62765957],
       [0.67021277, 0.74468085]]

# %%
# 4 Clusters - preparation, correct interval
# pca_dims = 10, N_samples = 15

acc = [[0.73404255, 0.55319149],
       [0.64893617, 0.56382979],
       [0.62765957, 0.58510638],
       [0.54255319, 0.64893617],
       [0.71276596, 0.46808511],
       [0.57446809, 0.63829787],
       [0.4893617 , 0.45744681],
       [0.5106383 , 0.43617021],
       [0.65957447, 0.40425532],
       [0.67021277, 0.43617021]]

# %% [markdown]
# # Dataset C19
# Only when computed with 2,3,4 clusters interval is correct

# %% [markdown]
# ## Cluster properties

# %% [markdown]
# ### Number of neurons per cluster

# %%
# 4 Clusters (Louvain)
neurons_per_cluster = [75, 58, 75, 87]

# 3 Clusters
neurons_per_cluster = [75, 133, 87]

# %% [markdown]
# ### PCA

# %%
# 7 Clusters
PCA_dims = 12 # to get 85% explained variance in smallest cluster

# 6 Clusters
PCA_dims = 14 # to get 85% explained variance in smallest cluster

# 4 Clusters (Louvain)
PCA_dims = [33, 37, 35, 52] # to get 85% explained variance in each cluster

# 4 Clusters - correct interval (movement)
PCA_dims = [30, 36, 34, 48] # to get 85% explained variance in each cluster

# 4 Clusters - correct interval (preparation)
PCA_dims = [33, 35, 38, 49] # to get 85% explained variance in each cluster

# 3 Clusters
PCA_dims = [33, 72, 51] # to get 85% explained variance in each cluster

# %% [markdown]
# ### Firing rate

# %%
# 7 Clusters
meanFR = [ 6.46432202, 10.80949237, 12.34872461, 5.6364084, 9.54895389, 9.50404562, 6.4712019 ]
smeFR = [0.86127408, 1.01375982, 1.88131955, 0.55617709, 1.14093272, 1.09277103, 0.68583516]
FR_overall_mean = 8.83257046998453
FR_overall_sme = 0.43192637911253284
max_FR = [17.09114787, 38.92104192, 32.30993815, 20.34586149, 30.88446888, 37.85624779, 16.90720826]

# 6 Clusters
avg_FR = [10.69541931, 11.56407395, 5.5677009, 7.56414557, 11.07898673, 6.60557909]
sme_FR = [1.07130993, 1.69179598, 0.53930571, 0.62887732, 1.19093986, 0.677443  ]
overall_FR_mean = 8.83257046998453
overall_FR_sme = 0.43192637911253284
max_FR = [37.85624779, 32.30993815, 20.34586149, 25.04766121, 38.92104192, 16.90720826]

# 4 CLusters (Louvain) - movement
meanFR = [10.65481835, 8.83887422, 12.24137832, 5.84664005]
smeFR = [1.14930254, 0.87489812, 1.17503089, 0.4301178 ]
FR_overall_mean = 9.283142848140548
FR_overall_sme = 0.49132703204387457
maxFR = [39.43140346, 39.21447418, 46.1113445, 20.30464577]

# 4 CLusters (Louvain) - preparation
meanFR = [11.5001918, 8.14301211, 11.2637229, 6.23443844]
smeFR = [1.0238001, 0.82446978, 0.96293874, 0.49970274]
FR_overall_mean = 9.227065930834895
FR_overall_sme = 0.4398212291811823
maxFR = [33.66989243, 38.51386875, 37.80539693, 25.43735211]

# 3 Clusters
meanFR = [10.65481835, 10.75757954, 5.84664005]
smeFR = [1.14930254, 0.77847817, 0.4301178 ]
FR_overall_mean = 9.283142848140548
FR_overall_sme = 0.49132703204387457
max_FR = [39.43140346, 46.1113445, 20.30464577]

# 2 Clusters
meanFR = [10.72052623, 5.84664005]
smeFR = [0.647712, 0.4301178]
FR_overall_mean = 9.283142848140548
FR_overall_sme = 0.49132703204387457
max_FR = [46.1113445, 20.30464577]

# %% [markdown]
# ### Peak to Trough

# %%
# 7 Clusters
PTT_mean = [0.3652173913043478, 0.17342465753424655, 0.242, 0.5458928571428572, 0.3075, 0.21857142857142856, 0.4838709677419355]
PTT_sme = [0.03598923156114844, 0.003401120090146718, 0.007061633427661525, 0.02000761459909862, 0.009992184445855671, 0.006645983464462767, 0.007831171463059498]
PTT_overall_mean = 0.3232881355932203
PTT_overall_sme = 0.009746402636897562

# 6 Clusters
PTT_mean = [0.2748214285714286, 0.23249999999999998, 0.5451724137931034, 0.2747368421052631, 0.16947368421052633, 0.47322580645161294]
PTT_sme = [0.009364334311974023, 0.007395099728874519, 0.019327642159490736, 0.018137509131580815, 0.0038310025643813706, 0.009353582749662024]
PTT_overall_mean = 0.3232881355932203
PTT_overall_sme = 0.009746402636897562

# 4 Clusters (Louvain)
meanPTT = [0.272, 0.2746551724137931, 0.17959999999999998, 0.5237931034482757]
smePTT = [0.007742523275177586, 0.017824977327353116, 0.003979681729317894, 0.013556633292633949]
PTT_overall_mean = 0.3232881355932203
PTT_overall_sme = 0.009746402636897562

# 3 Clusters
meanPTT = [0.272, 0.22105263157894736, 0.5237931034482757]
smePTT = [0.007742523275177586, 0.009064603253484417, 0.013556633292633949]
PTT_overall_mean = 0.3232881355932203
PTT_overall_sme = 0.009746402636897562

# 2 Clusters
meanPTT = [0.2394230769230769, 0.5237931034482757]
smePTT = [0.00665328124205225, 0.013556633292633949]
PTT_overall_mean = 0.3232881355932203
PTT_overall_sme = 0.009746402636897562

# %% [markdown]
# ### AP width

# %%
# 4 Clusters (Louvain)
meanAP = [0.1368, 0.12310344827586207, 0.11279999999999998, 0.1772413793103448]
smeAP = [0.0026677331200852905, 0.0015840858485974684, 0.0023213789005675054, 0.0079778555570076]
AP_overall_mean = 0.13993220338983048
AP_overall_sme = 0.002943494756185774

# 3 Clusters (Louvain)
meanAP = [0.1368, 0.11729323308270675, 0.1772413793103448]
smeAP = [0.0026677331200852905, 0.0015450270526639394, 0.0079778555570076]
AP_overall_mean = 0.13993220338983048
AP_overall_sme = 0.002943494756185774

# 2 Clusters (Louvain)
meanAP = [0.12432692307692307, 0.1772413793103448]
smeAP = [0.0015241656191703383, 0.0079778555570076]
AP_overall_mean = 0.13993220338983048
AP_overall_sme = 0.002943494756185774

# %% [markdown]
# ## R2 for Velocity decoding (LSTM)

# %%
# 7 Clusters
# R2 from each cluster
r2 = [[-0.04667145,  0.46921439,  0.54322611,  0.38703266,  0.41354268, 0.278, -0.013],
       [-0.05843315,  0.43771059,  0.55968881,  0.12635877,  0.28273303, 0.262, -0.045],
       [-0.03136327,  0.51447994,  0.52303314,  0.29534883,  0.49115523, 0.178,  0.105],
       [-0.05211946,  0.61474456,  0.60880336,  0.36788561,  0.51538624, 0.283, -0.029],
       [-0.04525696,  0.51378475,  0.53279361,  0.21566785,  0.33664753, -0.469,  0.034],
       [-0.09319078,  0.66718692,  0.55671579,  0.36118449,  0.43118368, 0.389,  0.055],
       [-0.06638953,  0.55038133,  0.49849223,  0.10044153,  0.06236028, 0.144,  0.09377563],
       [-0.10349137,  0.5001587 ,  0.58726691,  0.37909616,  0.49090266, -0.204, -0.041],
       [-0.10481612,  0.58157055,  0.50071176,  0.29014636,  0.43137923, 0.31 ,  0.008],
       [-0.11369792,  0.66154268,  0.59174485,  0.22747525,   0.0530779 , 0.259,  0.026]]


# R2 sampling neurons randomly from dataset
r2_all = [0.2008393 ,  0.38065422, -0.01071445,  0.35802646,  0.47784013,
          0.41741386,  0.51015032, 0.57110042, 0.52139952, 0.41119729]

# %%
# 4 Clusters - correct time interval
# R2 from each cluster
r2 = [[0.69769582, 0.46559943, 0.73024136, 0.56559442],
       [0.7461994 , 0.45198536, 0.74236074, 0.57096739],
       [0.77003291, 0.51529288, 0.72753891, 0.4722226 ],
       [0.73645249, 0.4507195 , 0.67709964, 0.59805566],
       [0.75415431, 0.4744763 , 0.72575772, 0.64098665],
       [0.76026422, 0.52830004, 0.69270418, 0.59200074],
       [0.71210494, 0.51312046, 0.74435956, 0.5874625 ],
       [0.71425813, 0.45833375, 0.72871525, 0.4487798 ],
       [0.70980356, 0.53182681, 0.71437418, 0.44430007],
       [0.75020772, 0.45435731, 0.72856192, 0.57274672]]

# R2 sampling neurons randomly from dataset
r2_all = [0.73004527, 0.64521315, 0.64074874, 0.71642717, 0.66570785,
          0.65330659, 0.57460691, 0.56035182, 0.69240019, 0.59663886,
          0.72397785, 0.63487378]

# %%
# 3 Clusters
# N_samples=15, pca_dims=10

# R2 from each cluster
r2 = [[0.45628663, 0.41024679, 0.32067956],
       [0.55021371, 0.49628132, 0.32890008],
       [0.42723591, 0.24234233, 0.16360976],
       [0.57906237, 0.4090787 , 0.33641887],
       [0.369889  , 0.46514323, 0.21770267],
       [0.60503979, 0.08815657, 0.34972786],
       [0.70040985, 0.36839099, 0.05800577],
       [0.63112987, 0.30269138, 0.44793241],
       [0.57585737, 0.32573785, 0.09412909],
       [0.44672822, 0.23416869, 0.11269312]]

# R2 sampling neurons randomly from dataset
r2_all = [ 0.29568326,  0.38294253,  0.4555153, 0.42383035,  0.32174134, -0.21618035,
          0.63798835,  0.35089129,  0.48949146, 0.53810719,  0.5213182 , -0.02982045]

# %%
# 2 Clusters
# N_samples=15, pca_dims=10

# R2 from each cluster
r2 = [[0.30217209, 0.35723797],
       [0.38213995, 0.09845961],
       [0.51357372, 0.39119512],
       [0.27083262, 0.39760383],
       [0.56498275, 0.31199811],
       [0.61820485, 0.27007657],
       [0.18623009, 0.13865947],
       [0.61820443, 0.23546246],
       [0.18101927, 0.17310145],
       [0.32986721, 0.05927903]]

# R2 sampling neurons randomly from dataset
r2_all = [0.37562016, 0.36178921, 0.5551443 , 0.18398579, 0.1791055 ,
          0.45367698, 0.22969824, 0.24078788, 0.41458077, 0.12047787]

# %% [markdown]
# ## Accuracy for Target classifier (LSTM)

# %%
# 7 Clusters
# acc from each cluster
acc = [[0.39583333, 0.66666667, 0.3125    , 0.58333333, 0.47916667, 0.47916667, 0.35416667],
       [0.35416667, 0.39583333, 0.66666667, 0.58333333, 0.54166667, 0.33333333, 0.3125    ],
       [0.39583333, 0.47916667, 0.52083333, 0.35416667, 0.54166667, 0.27083333, 0.39583333],
       [0.41666667, 0.47916667, 0.70833333, 0.5625    , 0.5625    , 0.375     , 0.4375    ],
       [0.33333333, 0.60416667, 0.58333333, 0.25      , 0.47916667, 0.375     , 0.29166667],
       [0.41666667, 0.60416667, 0.58333333, 0.35416667, 0.35416667, 0.29166667, 0.375     ],
       [0.35416667, 0.54166667, 0.72916667, 0.625     , 0.64583333, 0.375     , 0.4375    ],
       [0.41666667, 0.5625    , 0.54166667, 0.3125    , 0.58333333, 0.39583333, 0.41666667],
       [0.375     , 0.45833333, 0.70833333, 0.29166667, 0.5625    , 0.33333333, 0.35416667],
       [0.47916667, 0.52083333, 0.58333333, 0.4375    , 0.58333333, 0.375     , 0.27083333]]

# acc sampling neurons randomly from dataset
acc_all = [0.52083333, 0.6875    , 0.47916667, 0.39583333, 0.5625,
           0.64583333, 0.58333333, 0.625     , 0.58333333, 0.54166667]

# %%
# 4 Clusters - pca_dims = 30
# acc from each cluster
acc = [[0.7875, 0.6625, 0.7625, 0.4375],
       [0.7875, 0.6375, 0.625 , 0.5   ],
       [0.7375, 0.625 , 0.7375, 0.525 ],
       [0.725 , 0.5875, 0.725 , 0.525 ],
       [0.65  , 0.6   , 0.7625, 0.5875],
       [0.7375, 0.625 , 0.75  , 0.4875],
       [0.8625, 0.5375, 0.6625, 0.525 ],
       [0.8125, 0.6375, 0.7   , 0.6   ],
       [0.7625, 0.6375, 0.75  , 0.65  ],
       [0.65  , 0.6125, 0.6125, 0.575 ]]

# acc sampling neurons randomly from dataset
acc_all = [0.6625, 0.5875, 0.75  , 0.6875, 0.8   ,
            0.6125, 0.6125, 0.8   , 0.675 , 0.6   ]

# %%
# 4 Clusters - pca_dims = 11
# acc from each cluster
acc = [[0.7   , 0.5   , 0.6   , 0.4875],
       [0.75  , 0.45  , 0.65  , 0.65  ],
       [0.7125, 0.6375, 0.7375, 0.55  ],
       [0.675 , 0.625 , 0.7   , 0.625 ],
       [0.6   , 0.5   , 0.7375, 0.4375],
       [0.7625, 0.6125, 0.7375, 0.55  ],
       [0.6875, 0.525 , 0.6125, 0.55  ],
       [0.725 , 0.55  , 0.5   , 0.5875],
       [0.6375, 0.5625, 0.775 , 0.5375],
       [0.675 , 0.5375, 0.7875, 0.4875]]

# acc sampling neurons randomly from dataset
acc_all = [0.6125, 0.625 , 0.5875, 0.6125, 0.6125,
            0.6125, 0.6875, 0.5375, 0.575 , 0.7   ]

# %%
# 4 Clusters - avg pca
# pca_dims=10, N_samples=15
# acc from each cluster
acc = [[0.525 , 0.375 , 0.475 , 0.4   ],
       [0.55  , 0.4375, 0.45  , 0.4375],
       [0.5625, 0.3875, 0.5875, 0.2875],
       [0.4625, 0.375 , 0.475 , 0.35  ],
       [0.4875, 0.3625, 0.5375, 0.4   ],
       [0.5875, 0.225 , 0.3125, 0.3375],
       [0.5   , 0.4375, 0.4   , 0.4125],
       [0.45  , 0.4   , 0.425 , 0.4   ],
       [0.55  , 0.3375, 0.4375, 0.3125],
       [0.525 , 0.425 , 0.525 , 0.3875]]

# acc sampling neurons randomly from dataset
acc_all = [0.6   , 0.475 , 0.5125, 0.5125, 0.625 ,
           0.425 , 0.5125, 0.35, 0.375 , 0.5   ,
           0.4875, 0.475 ]

# %% [markdown]
# ## Accuracy for Target classifier (GNB)

# %%
# 7 Clusters
# acc from each cluster
accGNB = [[0.45833333, 0.60416667, 0.70833333, 0.5       , 0.625     , 0.35416667, 0.375     ],
          [0.47916667, 0.66666667, 0.85416667, 0.54166667, 0.60416667, 0.41666667, 0.29166667],
          [0.45833333, 0.54166667, 0.79166667, 0.52083333, 0.47916667, 0.39583333, 0.35416667],
          [0.52083333, 0.52083333, 0.77083333, 0.72916667, 0.60416667, 0.39583333, 0.33333333],
          [0.4375    , 0.66666667, 0.79166667, 0.41666667, 0.60416667, 0.35416667, 0.3125    ],
          [0.41666667, 0.66666667, 0.64583333, 0.60416667, 0.5625    , 0.33333333, 0.41666667],
          [0.45833333, 0.72916667, 0.72916667, 0.4375    , 0.4375    , 0.47916667, 0.47916667],
          [0.45833333, 0.66666667, 0.6875    , 0.625     , 0.60416667, 0.625     , 0.35416667],
          [0.45833333, 0.625     , 0.72916667, 0.5625    , 0.60416667, 0.39583333, 0.25      ],
          [0.41666667, 0.66666667, 0.79166667, 0.41666667, 0.66666667, 0.45833333, 0.39583333]]

# acc sampling neurons randomly from dataset
acc_allGNB = [0.66666667, 0.47916667, 0.41666667, 0.70833333, 0.54166667,
              0.5625    , 0.41666667, 0.52083333, 0.5       , 0.5625]

# %%
# 4 Clusters
# acc from each cluster
accGNB = [[0.6875, 0.575 , 0.775 , 0.6625],
       [0.725 , 0.5   , 0.75  , 0.5875],
       [0.825 , 0.6   , 0.8125, 0.525 ],
       [0.8125, 0.5375, 0.6   , 0.6375],
       [0.75  , 0.6   , 0.7625, 0.6125],
       [0.725 , 0.4375, 0.8   , 0.6625],
       [0.6625, 0.6375, 0.75  , 0.5   ],
       [0.7375, 0.5625, 0.775 , 0.6625],
       [0.8125, 0.575 , 0.5875, 0.675 ],
       [0.7375, 0.525 , 0.75  , 0.45  ]]

# acc sampling neurons randomly from dataset
acc_allGNB = [0.6375, 0.5875, 0.7625, 0.5375, 0.65  ,
              0.7375, 0.7   , 0.7375, 0.6625, 0.6125]

# %% [markdown]
# ## M1 vs PMd

# %%
# 4 Clusters - movement, correct interval
# pca_dims = 10, N_samples = 35
r2 = [[0.59182572, 0.52169531],
       [0.66785174, 0.41820323],
       [0.76799046, 0.38991485],
       [0.63375097, 0.53537696],
       [0.70390195, 0.55099863],
       [0.62808339, 0.58677276],
       [0.7066327 , 0.28007312],
       [0.68495181, 0.437944  ],
       [0.66807022, 0.46040314],
       [0.68047975, 0.39431983]]

# %%
# 4 Clusters - preparation, correct interval
# pca_dims = 10, N_samples = 35
acc = [[0.5   , 0.5625],
       [0.625 , 0.675 ],
       [0.75  , 0.5   ],
       [0.7125, 0.5125],
       [0.5875, 0.575 ],
       [0.55  , 0.5875],
       [0.7125, 0.4   ],
       [0.7625, 0.5625],
       [0.65  , 0.625 ],
       [0.7   , 0.4875]]

# %%
# 4 Clusters - preparation, correct interval
# pca_dims = 20, N_samples = 35
acc = [[0.6   , 0.5625],
       [0.6875, 0.675 ],
       [0.6375, 0.6375],
       [0.6375, 0.6375],
       [0.625 , 0.6375],
       [0.6875, 0.675 ],
       [0.625 , 0.6375],
       [0.7125, 0.6125],
       [0.7625, 0.75  ],
       [0.6125, 0.6375]]

# %% [markdown]
# ## dPCA

# %%
# velocity decoding
# N_samples = 15

# using the same transformation matrix at every step
r2_st = [[0.68394521, 0.49386331, 0.60264751, 0.57677207],
       [0.58035793, 0.41709021, 0.64240334, 0.53633999],
       [0.59450683, 0.40492992, 0.72976172, 0.58601179],
       [0.75227583, 0.58507501, 0.69437191, 0.55934872],
       [0.7383135 , 0.40138906, 0.5075214 , 0.58059592],
       [0.74851475, 0.43445017, 0.65411637, 0.62772572],
       [0.57528459, 0.50542841, 0.69311159, 0.62756853],
       [0.66852838, 0.48080045, 0.56814375, 0.59389638],
       [0.68286066, 0.32438511, 0.68443948, 0.62119528],
       [0.7357141 , 0.52295557, 0.54943477, 0.55825175]]

r2_t = [[0.6474154 , 0.43870625, 0.49756218, 0.53966017],
       [0.66715742, 0.51139742, 0.71788369, 0.60348073],
       [0.59865735, 0.52882819, 0.58710702, 0.49931862],
       [0.70508447, 0.43078267, 0.67878676, 0.5197584 ],
       [0.64854829, 0.41829679, 0.60784969, 0.67227634],
       [0.63935981, 0.52135545, 0.63875009, 0.59506935],
       [0.59997986, 0.55478782, 0.68606386, 0.71418879],
       [0.65961095, 0.5233292 , 0.66285677, 0.52532911],
       [0.56146769, 0.40896158, 0.55297424, 0.57419539],
       [0.64369613, 0.3948967 , 0.502351  , 0.56864406]]

r2_s = [[0.62335674, 0.36164164, 0.54474606, 0.39614301],
       [0.63184177, 0.34915213, 0.56147733, 0.62712785],
       [0.56970841, 0.49966952, 0.59692664, 0.38633152],
       [0.64837995, 0.3832144 , 0.57143275, 0.53515308],
       [0.54267782, 0.42593563, 0.59478636, 0.54677521],
       [0.53827311, 0.57824889, 0.52394471, 0.57689454],
       [0.65184895, 0.3903    , 0.60071554, 0.64963982],
       [0.62149902, 0.29588582, 0.62797979, 0.5495999 ],
       [0.61458518, 0.47305408, 0.67204572, 0.63677656],
       [0.63759061, 0.40127356, 0.62602775, 0.38645573]]

# computing new transformation matrix at every iteration
r2_st = [[0.5751877 , 0.36508708, 0.52593937, 0.41333456],
       [0.61527872, 0.37179959, 0.5608289 , 0.41442675],
       [0.64017177, 0.29892706, 0.69300511, 0.38481414],
       [0.68033038, 0.33824281, 0.72130082, 0.52954574],
       [0.65978123, 0.34128669, 0.46299395, 0.43136723],
       [0.56178303, 0.45811696, 0.4439034 , 0.42456374],
       [0.62228696, 0.31726884, 0.6175805 , 0.47098181],
       [0.55637886, 0.3502686 , 0.58474325, 0.42018554],
       [0.65479665, 0.50733136, 0.5364215 , 0.43071579],
       [0.70119112, 0.41008428, 0.51140139, 0.44411189]]

# %% [markdown]
# # Dataset M17

# %% [markdown]
# ## Cluster properties

# %% [markdown]
# ### Number of neurons per cluster

# %%
# 4 Clusters
neurons_per_cluster = [40, 31, 42, 35]

# %% [markdown]
# ### PCA

# %%
# 4 Clusters - movement
PCA_dims = [18, 12, 21, 18] # to get 85% explained variance in each cluster

# 4 Clusters - preparation
PCA_dims = [18, 12, 21, 19] # to get 85% explained variance in each cluster

# %% [markdown]
# ### Firing rate

# %%
# 4 CLusters - movement
meanFR = [6.0324585, 3.21736861, 2.42392564, 2.68225012] 
smeFR = [1.17784606, 0.80217909, 0.37783007, 0.4371109 ]
FR_overall_mean = 3.6264891756229622
FR_overall_sme = 0.40836008989954703
maxFR = [34.68283078, 21.80589398, 11.0409893, 10.74687484]

# 4 CLusters - movement - not combining bins (correct)
meanFR = [7.26117947, 3.70132669, 2.60155079, 2.85265465]
smeFR = [1.56563883, 1.0088101, 0.43725934, 0.48745763]
FR_overall_mean = 4.150651026116968
FR_overall_sme = 0.5269120177579365
maxFR = [47.85937319, 27.6621761, 12.82516182, 12.08486096]

# 4 CLusters - preparation
meanFR = [5.82248978, 3.11538015, 2.50333361, 2.67173703]
smeFR = [1.06087363, 0.69617747, 0.4063437, 0.39261648]
FR_overall_mean = 3.568426913591632
FR_overall_sme = 0.37204903869761685
maxFR = [32.02879778, 18.59356108, 12.78082888, 9.61903258]

# 4 CLusters - preparation - not combining bins (correct)
meanFR = [6.95180198, 3.54154037, 2.73670969, 2.83840647]
smeFR = [1.39689522, 0.84138987, 0.47483985, 0.42480134]
FR_overall_mean = 4.068553136000563
FR_overall_sme = 0.47248166354646237
maxFR = [44.08610874, 22.98330775, 15.04449666, 10.57148468]

# 3 CLusters - movement
meanFR = [4.80333475, 2.42392564, 2.68225012]
smeFR = [0.76841449, 0.37783007, 0.4371109 ]
FR_overall_mean = 3.6264891756229622
FR_overall_sme = 0.40836008989954703
maxFR = [34.68283078, 11.0409893, 10.74687484]

# 2 CLusters - movement
meanFR = [4.88764078, 2.52497702]
smeFR = [0.78829013, 0.27979466]
FR_overall_mean = 3.6264891756229622
FR_overall_sme = 0.40836008989954703
maxFR = [34., 11., 10.]

# %% [markdown]
# ### Peak to trough

# %%
# 4 Clusters
meanPTT = [0.24074999999999996, 0.24967741935483873, 0.3457142857142857, 0.4105714285714286]
smePTT = [0.008713405620077604, 0.006475502077252058, 0.021600219557607093, 0.011862772206844693]
PTT_overall_mean = 0.3125675675675675
PTT_overall_sme = 0.009235832348780343

# 3 Clusters
meanPTT = [0.24464788732394357, 0.3457142857142857, 0.4105714285714286]
smePTT = [0.005689272649968285, 0.021600219557607093, 0.011862772206844693]
PTT_overall_mean = 0.3125675675675675
PTT_overall_sme = 0.009235832348780343

# 2 Clusters
meanPTT = [0.24173913043478254, 0.3744303797468354]
smePTT = [0.005461120804626793, 0.01314232157656419]
PTT_overall_mean = 0.3125675675675675
PTT_overall_sme = 0.009235832348780343

# %% [markdown]
# ### AP width

# %%
# 4 Clusters (Louvain)
meanAP = [0.11775, 0.12096774193548386, 0.1242857142857143, 0.15685714285714286]
smeAP = [0.0032497596064939935, 0.002898018222337193, 0.003436215967445456, 0.0029903635318265457]
AP_overall_mean = 0.12952702702702698
AP_overall_sme = 0.0020479426764847333

# 3 Clusters
meanAP = [0.11915492957746475, 0.1242857142857143, 0.15685714285714286]
smeAP = [0.0022335957035330895, 0.003436215967445456, 0.0029903635318265457]
AP_overall_mean = 0.12952702702702698
AP_overall_sme = 0.0020479426764847333

# 2 Clusters
meanAP = [0.11782608695652172, 0.13974683544303795]
smeAP = [0.002068655315112901, 0.002935915887835065]
AP_overall_mean = 0.12952702702702698
AP_overall_sme = 0.0020479426764847333

# %% [markdown]
# ## R2 for Velocity decoding (LSTM)

# %%
# 4 Clusters
# R2 from each cluster
r2 = [[ 0.61687257,  0.58806707,  0.10871926,  0.47752232],
       [ 0.62629377,  0.53836619,  0.38770626,  0.14432255],
       [ 0.49528569,  0.23036508,  0.20782741,  0.28571036],
       [ 0.60351254,  0.57807589,  0.36995736,  0.37362463],
       [ 0.37595353,  0.61801703,  0.00761749,  0.17729142],
       [ 0.61168058,  0.46956854,  0.47974725,  0.46409677],
       [ 0.55936888,  0.33134512,  0.28070233,  0.23468074],
       [ 0.57387874,  0.49391068,  0.14473376,  0.33967328],
       [ 0.61567344,  0.51196129, -0.09254761,  0.31232161],
       [ 0.5082322 ,  0.46304301,  0.41304901,  0.35703945]]

# R2 sampling neurons randomly from dataset
r2_all = [0.21273893, 0.45307798, 0.20762309, 0.40227711, 0.43967809,
          0.27170806, 0.36438225, 0.05817502, 0.57889061, 0.41274894,
          0.20149007, 0.37274667]

# %%
# 4 Clusters - no combine bins (correct)
# R2 from each cluster
r2 = [[ 0.10414619,  0.35292097,  0.45921684, -0.28487511],
       [ 0.48001257,  0.42906365,  0.44177819,  0.24678111],
       [ 0.55937506,  0.4529264 ,  0.28369994,  0.3248124 ],
       [ 0.63331642,  0.45325204,  0.0650452 ,  0.3287076 ],
       [ 0.25087665,  0.51775143, -0.02442328, -0.11037316],
       [ 0.64943244,  0.47360671,  0.00314953,  0.10235919],
       [ 0.58783573,  0.37221549,  0.23686809,  0.18241225],
       [ 0.69975061,  0.64995401,  0.07451837,  0.18787027],
       [ 0.60746911,  0.59156793,  0.15591757,  0.4934848 ],
       [ 0.39102454,  0.51586562,  0.30509955, -0.0932007 ]]

# R2 sampling neurons randomly from dataset
r2_all = [ 0.2379427 ,  0.6021562 ,  0.54270094, -0.09163102, 0.5412298 ,
          0.34478205,  0.31355407,  0.12191253, 0.2568103 ,  0.23486749,
          0.03962141,  0.56552429]

# %%
# 4 Clusters - abs(vel)
# R2 from each cluster
r2 = [[ 0.2231715 ,  0.39324913,  0.01969159, -0.00300429],
       [-0.08279576,  0.35776622,  0.07486519,  0.07436082],
       [ 0.1983754 ,  0.05074562,  0.13125253, -0.15631173],
       [ 0.32356779,  0.08466134,  0.00729898, -0.00217664],
       [ 0.38439496,  0.18247922, -0.12880192,  0.28485846],
       [ 0.42548629,  0.39811066, -0.087903  ,  0.18063813],
       [ 0.52416694,  0.13315773,  0.005797  ,  0.15538723],
       [ 0.49708727,  0.25007584, -0.06650381, -0.21931585],
       [ 0.10167167,  0.11709087, -0.09817656,  0.11678712],
       [ 0.39748916,  0.16064535, -0.15843389,  0.12316144]]

# R2 sampling neurons randomly from dataset
r2_all =

# %%
# 3 Clusters
# R2 from each cluster
r2 = [[ 0.62561198,  0.05071501,  0.54115969],
       [ 0.57657939,  0.05009936,  0.16231122],
       [ 0.46881162,  0.4427144 ,  0.31978516],
       [ 0.36089598,  0.14727868,  0.34119849],
       [ 0.5476532 , -0.09565725,  0.21056068],
       [ 0.59977859,  0.22340245,  0.19972042],
       [ 0.59674715,  0.1585845 ,  0.24718325],
       [ 0.45979299,  0.0519102 ,  0.49187813],
       [ 0.66138589,  0.40174143,  0.36708827],
       [ 0.52705275,  0.55575664,  0.43496063]]

# R2 sampling neurons randomly from dataset
r2_all = [0.30226417, 0.3753001 , 0.26235046, 0.24964375, 0.58026272, 0.22475595,
          0.27069728, 0.49584634, 0.32732233, 0.55167852, 0.37631348, 0.46017093]

# %%
# 2 Clusters
# R2 from each cluster
r2 = [[ 0.34265055, -0.05074034],
       [ 0.63462429,  0.17642581],
       [ 0.6217527 ,  0.29970968],
       [ 0.54736286,  0.41904807],
       [ 0.52471471,  0.17554265],
       [ 0.25237075,  0.27453584],
       [ 0.482029  ,  0.27598903],
       [ 0.63549075,  0.4069976 ],
       [ 0.52342627,  0.09699134],
       [ 0.53996219,  0.36423241]]

# R2 sampling neurons randomly from dataset
r2_all = [0.41288762, 0.32117275, 0.23747591, 0.30841583, 0.11993348,
          0.33604025, 0.58779764, 0.38901519, 0.13235836, 0.66415249]

# %% [markdown]
# ## Accuracy for Target classifier (LSTM)

# %%
# 4 Clusters - pca_dims = 10
# acc from each cluster
acc = [[0.63157895, 0.63157895, 0.57894737, 0.42105263],
       [0.63157895, 0.63157895, 0.73684211, 0.42105263],
       [0.68421053, 0.68421053, 0.52631579, 0.31578947],
       [0.42105263, 0.36842105, 0.42105263, 0.36842105],
       [0.73684211, 0.57894737, 0.26315789, 0.31578947],
       [0.63157895, 0.52631579, 0.36842105, 0.15789474],
       [0.42105263, 0.42105263, 0.31578947, 0.21052632],
       [0.57894737, 0.73684211, 0.57894737, 0.36842105],
       [0.47368421, 0.42105263, 0.31578947, 0.36842105],
       [0.84210526, 0.47368421, 0.31578947, 0.26315789]]

# acc sampling neurons randomly from dataset
acc_all = [0.42105263, 0.26315789, 0.47368421, 0.36842105, 0.57894737,
           0.73684211, 0.36842105, 0.42105263, 0.31578947, 0.52631579,
           0.42105263, 0.47368421]

# %%
# 4 Clusters - pca_dims = 10, on avg PC
# acc from each cluster
acc = [[0.47368421, 0.36842105, 0.21052632, 0.31578947],
       [0.57894737, 0.52631579, 0.26315789, 0.10526316],
       [0.47368421, 0.52631579, 0.21052632, 0.31578947],
       [0.42105263, 0.36842105, 0.36842105, 0.26315789],
       [0.47368421, 0.31578947, 0.15789474, 0.15789474],
       [0.42105263, 0.57894737, 0.31578947, 0.31578947],
       [0.47368421, 0.47368421, 0.31578947, 0.21052632],
       [0.47368421, 0.36842105, 0.42105263, 0.26315789],
       [0.31578947, 0.31578947, 0.31578947, 0.21052632],
       [0.52631579, 0.52631579, 0.36842105, 0.21052632]]

# acc sampling neurons randomly from dataset
acc_all = [0.42105263, 0.42105263, 0.47368421, 0.57894737, 0.47368421,
               0.47368421, 0.26315789, 0.52631579, 0.36842105, 0.57894737,
               0.47368421, 0.21052632]

# %%
# 4 Clusters - pca_dims = 10, on avg PC, no combine bins (correct)
# acc from each cluster
acc = [[0.42105263, 0.31578947, 0.31578947, 0.31578947],
       [0.73684211, 0.42105263, 0.26315789, 0.15789474],
       [0.52631579, 0.36842105, 0.31578947, 0.31578947],
       [0.42105263, 0.47368421, 0.31578947, 0.42105263],
       [0.36842105, 0.21052632, 0.52631579, 0.36842105],
       [0.47368421, 0.31578947, 0.26315789, 0.31578947],
       [0.42105263, 0.36842105, 0.47368421, 0.26315789],
       [0.42105263, 0.52631579, 0.47368421, 0.31578947],
       [0.52631579, 0.36842105, 0.21052632, 0.26315789],
       [0.36842105, 0.42105263, 0.31578947, 0.15789474]]

# acc sampling neurons randomly from dataset
acc_all = [0.47368421, 0.63157895, 0.31578947, 0.47368421, 0.36842105,
           0.36842105, 0.31578947, 0.36842105, 0.26315789, 0.42105263,
           0.47368421, 0.57894737]

# %% [markdown]
# ## M1 vs PMd

# %%
# 4 Clusters - movement
# pca_dims = 10, N_samples = 35
r2 = [[0.63043037, 0.38981508],
       [0.7137753 , 0.40738762],
       [0.78708507, 0.32896034],
       [0.68165434, 0.28442861],
       [0.76059136, 0.45246081],
       [0.62796224, 0.30339068],
       [0.7067176 , 0.53478239],
       [0.69901597, 0.40222704],
       [0.72992304, 0.46458588],
       [0.74406929, 0.49834875]]

# pca_dims = 20, N_samples = 35
r2 = [[0.75502604, 0.48212794],
       [0.73955137, 0.62752106],
       [0.70734926, 0.38410407],
       [0.81403   , 0.62547648],
       [0.72440375, 0.67121684],
       [0.76754913, 0.44805812],
       [0.80709039, 0.48379366],
       [0.67829433, 0.44398606],
       [0.61266859, 0.50299785],
       [0.64509399, 0.33437841]]

# %%
# 4 Clusters - preparation
# pca_dims = 10, N_samples = 35
r2 = [[0.84210526, 0.63157895],
       [0.89473684, 0.47368421],
       [0.68421053, 0.57894737],
       [0.73684211, 0.63157895],
       [0.68421053, 0.42105263],
       [0.78947368, 0.63157895],
       [0.68421053, 0.63157895],
       [0.78947368, 0.63157895],
       [0.78947368, 0.57894737],
       [0.78947368, 0.68421053]]

# pca_dims = 20, N_samples = 35
r2 = [[0.84210526, 0.63157895],
       [0.68421053, 0.57894737],
       [0.73684211, 0.73684211],
       [0.78947368, 0.78947368],
       [0.68421053, 0.52631579],
       [0.73684211, 0.42105263],
       [0.78947368, 0.52631579],
       [0.78947368, 0.57894737],
       [0.73684211, 0.73684211],
       [0.73684211, 0.42105263]]

# pca_dims = 30, N_samples = 35
r2 = [[0.73684211, 0.63157895],
       [0.73684211, 0.57894737],
       [0.63157895, 0.63157895],
       [0.73684211, 0.47368421],
       [0.78947368, 0.57894737],
       [0.73684211, 0.52631579],
       [0.57894737, 0.57894737],
       [0.68421053, 0.63157895],
       [0.68421053, 0.73684211],
       [0.68421053, 0.57894737]]

# %% [markdown]
# # Dataset M18

# %% [markdown]
# ## Cluster Properties

# %% [markdown]
# ### Number of neurons per cluster

# %%
# 4 Clusters
neurons_per_cluster = [31, 30, 37, 61]

# %% [markdown]
# ### PCA

# %%
# 4 Clusters - movement
PCA_dims = [15, 15, 19, 24] # to get 85% explained variance in each cluster

# 4 Clusters - preparation
PCA_dims = [15, 16, 20, 25] # to get 85% explained variance in each cluster

# %% [markdown]
# ### Firing rate

# %%
# 4 CLusters - movement
meanFR = [3.37267038, 4.41618195, 1.97489766, 4.76831257]
smeFR = [1.15032052, 0.79365505, 0.45293866, 0.85448091]
FR_overall_mean = 3.779726541957582
FR_overall_sme = 0.4462154891974853
maxFR = [35.48050965, 16.69210181, 16.33585512, 31.40347511]

# 4 CLusters - movement - not combining bins (correct)
meanFR = [3.98180183, 4.99837112, 2.12049862, 5.6629661 ]
smeFR = [1.59362261, 0.98037768, 0.54845664, 1.12045292]
FR_overall_mean = 4.3854488768180095
FR_overall_sme = 0.5864421446999788
maxFR = [49.86136982, 20.60096337, 20.09329275, 42.77224917]

# 4 CLusters - preparation
meanFR = [3.32429033, 4.25316618, 2.13739428, 4.67545444]
smeFR = [1.08122532, 0.68951471, 0.49998559, 0.79399228]
FR_overall_mean = 3.741725125844111
FR_overall_sme = 0.417235050525808
maxFR = [33.37597484, 14.63134431, 18.73276644, 30.37784409]

# 4 CLusters - preparation - not combining bins (correct)
meanFR = [3.90660373, 4.7927523, 2.35547702, 5.5388433 ]
smeFR = [1.48313807, 0.82884873, 0.62513721, 1.03333077]
FR_overall_mean = 4.339052677215852
FR_overall_sme = 0.5441521858027007
maxFR = [46.44327318, 17.64108147, 23.59295695, 41.44703867]

# 3 CLusters - movement
meanFR = [3.37267038, 3.03430631, 4.77676648]
smeFR = [1.15032052, 0.46489963, 0.84074078]
FR_overall_mean = 3.779726541957582
FR_overall_sme = 0.4462154891974853
maxFR = [35.48050965, 16.69210181, 31.40347511]

# 2 CLusters - movement
meanFR = [3.00621395, 3.95227935]
smeFR = [1.18708913, 0.47588678]
FR_overall_mean = 3.779726541957582
FR_overall_sme = 0.4462154891974853
maxFR = [35.48050965, 31.40347511]

# %% [markdown]
# ### Peak to trough

# %%
# 4 Clusters
meanPTT = [0.47322580645161283, 0.21600000000000003, 0.33486486486486483, 0.2626229508196722]
smePTT = [0.00945317719934219, 0.006542170893518453, 0.01009539322881267, 0.007639772166107281]
PTT_overall_mean = 0.31169811320754715
PTT_overall_sme = 0.008275739052567002

# 3 Clusters
meanPTT = [0.47322580645161283, 0.28227272727272723, 0.26225806451612904]
smePTT = [0.00945317719934219, 0.009705950988854547, 0.007525258731913671]
PTT_overall_mean = 0.31169811320754715
PTT_overall_sme = 0.008275739052567002

# 2 Clusters
meanPTT = [0.4799999999999999, 0.27415384615384614]
smePTT = [0.008777877283695074, 0.006258518091591373]
PTT_overall_mean = 0.31169811320754715
PTT_overall_sme = 0.008275739052567002

# %% [markdown]
# ### AP width

# %%
# 4 Clusters
meanAP = [0.16451612903225804, 0.10400000000000001, 0.12405405405405405, 0.12245901639344263]
smeAP = [0.003316113646174277, 0.0027325202042558926, 0.002339343663126227, 0.0028924624514040766]
AP_overall_mean = 0.12754716981132072
AP_overall_sme = 0.002150753938347968

# 3 Clusters
meanAP = [0.16451612903225804, 0.11499999999999999, 0.12241935483870968]
smeAP = [0.003316113646174277, 0.002187807436089947, 0.002846081738600894]
AP_overall_mean = 0.12754716981132072
AP_overall_sme = 0.002150753938347968


# 2 Clusters
meanAP = [0.16551724137931037, 0.11907692307692308]
smeAP = [0.003468430989754599, 0.0018152742921045805]
AP_overall_mean = 0.12754716981132072
AP_overall_sme = 0.002150753938347968

# %% [markdown]
# ## R2 for Velocity decoding (LSTM)

# %%
# 4 Clusters
# R2 from each cluster
r2 = [[ 0.48650867,  0.62508355,  0.07607568,  0.4877921 ],
       [ 0.28411572,  0.68758833,  0.53316298,  0.58485657],
       [ 0.42287024,  0.63836172, -0.00151388,  0.58849218],
       [ 0.58006212,  0.67196496,  0.07944708,  0.63680827],
       [ 0.5370336 ,  0.63307087,  0.51445683,  0.72694099],
       [ 0.39551248,  0.60572834,  0.32910207,  0.65382388],
       [ 0.43800208,  0.59150165,  0.52804156,  0.72359277],
       [ 0.49563927,  0.59791964,  0.13274096,  0.70050074],
       [ 0.45553691,  0.72107068,  0.44309931,  0.46270047],
       [ 0.44245922,  0.69380205,  0.23852652,  0.66537187]]

# R2 sampling neurons randomly from dataset
r2_all = [0.55833078, 0.46609196, 0.66723304, 0.6546001, 0.56038903,
          0.63051737, 0.57451754, 0.4935652, 0.54642839, 0.68287678,
          0.6818829 , 0.60224168]

# %%
# 4 Clusters - no combine bins (correct)
# R2 from each cluster
r2 = [[ 0.30146695,  0.60901561, -0.2200439 ,  0.33469265],
       [ 0.46206127,  0.42980335, -0.07907122,  0.46285348],
       [ 0.36152266,  0.19365876,  0.24721725,  0.4168542 ],
       [ 0.39192327,  0.5487137 ,  0.27613763,  0.75700283],
       [ 0.45932108,  0.31569643,  0.33437815,  0.49547954],
       [-0.01038198,  0.31317951, -0.0623817 ,  0.537017  ],
       [ 0.14159304,  0.43484379,  0.44154588,  0.50069906],
       [ 0.27080936,  0.40607096,  0.52196411,  0.63262806],
       [ 0.30101664,  0.47847435,  0.31054083,  0.59239585],
       [ 0.42395455,  0.32211087,  0.14264983,  0.44384997]]

# R2 sampling neurons randomly from dataset
r2_all = [-0.10389008,  0.09865108,  0.10444034,  0.40419977, 0.52505678,
          0.48874214,  0.180712  ,  0.33292846, 0.24389287,  0.30256564,
          0.14993748,  0.09134825]

# %%
# 3 Clusters
# R2 from each cluster
r2 = [[0.33753025, 0.56213024, 0.34122558],
       [0.05337422, 0.58152104, 0.51133314],
       [0.51841939, 0.47010508, 0.61833664],
       [0.28260269, 0.43768191, 0.73645292],
       [0.4468106 , 0.47981546, 0.7251567 ],
       [0.35863703, 0.1867101 , 0.54884039],
       [0.39359289, 0.38371285, 0.47315243],
       [0.32408466, 0.50559011, 0.46987494],
       [0.29927698, 0.39309013, 0.47057632],
       [0.22720848, 0.293345  , 0.57696315]]

# R2 sampling neurons randomly from dataset
r2_all = [0.59352514, 0.42862712, 0.52486323, 0.25631539, 0.22594085, 0.43777864,
          0.48899114, 0.25336204, 0.33203205, 0.50030265, 0.45471021, 0.46280194]

# %%
# 2 Clusters
# R2 from each cluster
r2 = [[0.27402576, 0.60180667],
       [0.37433794, 0.52801405],
       [0.30803491, 0.32401873],
       [0.22654088, 0.34279845],
       [0.14376368, 0.4002589 ],
       [0.22055   , 0.39916924],
       [0.12401727, 0.61635802],
       [0.46383052, 0.33061631],
       [0.2648021 , 0.54396905],
       [0.30455959, 0.62278614]]

# R2 sampling neurons randomly from dataset
r2_all = [0.35038988, 0.22073105, 0.1556833 , 0.06853984, 0.53694004,
          0.37345258, 0.34665008, 0.42699279, 0.3955654 , 0.31233536]

# %% [markdown]
# ## Accuracy for Target classifier (LSTM)

# %%
# 4 Clusters - pca_dims = 11
# acc from each cluster
acc = [[0.54545455, 0.86363636, 0.59090909, 0.81818182],
       [0.40909091, 0.77272727, 0.54545455, 0.77272727],
       [0.54545455, 0.5       , 0.40909091, 0.5       ],
       [0.45454545, 0.5       , 0.36363636, 0.54545455],
       [0.5       , 0.59090909, 0.54545455, 0.77272727],
       [0.63636364, 0.40909091, 0.54545455, 0.59090909],
       [0.59090909, 0.63636364, 0.36363636, 0.59090909],
       [0.54545455, 0.59090909, 0.45454545, 0.54545455],
       [0.68181818, 0.31818182, 0.27272727, 0.59090909],
       [0.45454545, 0.68181818, 0.40909091, 0.81818182]]

# acc sampling neurons randomly from dataset
acc_all = [0.54545455, 0.45454545, 0.54545455, 0.59090909, 0.5,
           0.5, 0.77272727, 0.59090909, 0.40909091, 0.68181818,
           0.72727273, 0.68181818]

# %%
# 4 Clusters - pca_dims = 10, on avg PC
# acc from each cluster
acc = [[0.40909091, 0.45454545, 0.54545455, 0.63636364],
       [0.36363636, 0.5       , 0.54545455, 0.63636364],
       [0.5       , 0.40909091, 0.40909091, 0.59090909],
       [0.31818182, 0.5       , 0.54545455, 0.68181818],
       [0.45454545, 0.59090909, 0.40909091, 0.63636364],
       [0.5       , 0.5       , 0.40909091, 0.72727273],
       [0.63636364, 0.40909091, 0.45454545, 0.59090909],
       [0.40909091, 0.59090909, 0.18181818, 0.81818182],
       [0.31818182, 0.40909091, 0.45454545, 0.63636364],
       [0.45454545, 0.45454545, 0.40909091, 0.54545455]]

# acc sampling neurons randomly from dataset
acc_all = [0.59090909, 0.54545455, 0.40909091, 0.54545455, 0.45454545,
               0.40909091, 0.40909091, 0.54545455, 0.31818182, 0.36363636,
               0.31818182, 0.40909091]

# %%
# 4 Clusters - pca_dims = 10, on avg PC, no combbine bins
# acc from each cluster
acc = [[0.22727273, 0.40909091, 0.31818182, 0.77272727],
       [0.63636364, 0.40909091, 0.40909091, 0.45454545],
       [0.5       , 0.5       , 0.40909091, 0.40909091],
       [0.5       , 0.45454545, 0.40909091, 0.59090909],
       [0.5       , 0.22727273, 0.40909091, 0.40909091],
       [0.40909091, 0.45454545, 0.36363636, 0.40909091],
       [0.45454545, 0.59090909, 0.36363636, 0.54545455],
       [0.36363636, 0.59090909, 0.54545455, 0.54545455],
       [0.54545455, 0.31818182, 0.45454545, 0.54545455],
       [0.36363636, 0.31818182, 0.27272727, 0.45454545]]

# acc sampling neurons randomly from dataset
acc_all = [0.59090909, 0.54545455, 0.45454545, 0.40909091, 0.5,
           0.5       , 0.59090909, 0.45454545, 0.36363636, 0.40909091,
           0.5       , 0.5       ]

# %% [markdown]
# ## M1 vs PMd

# %%
# 4 Clusters - movement
# pca_dims = 10, N_samples = 35
r2 = [[0.727523  , 0.28295824],
       [0.73763737, 0.60017477],
       [0.70182099, 0.36401306],
       [0.73915531, 0.53793671],
       [0.71429542, 0.58977277],
       [0.72914716, 0.56782434],
       [0.73055307, 0.55974979],
       [0.67069916, 0.53374671],
       [0.73362815, 0.48757836],
       [0.66857673, 0.55590478]]

# pca_dims = 20, N_samples = 35
r2 = [[0.69898387, 0.54059661],
       [0.63327955, 0.64491595],
       [0.73445831, 0.60047298],
       [0.69602864, 0.56269474],
       [0.73587208, 0.60424372],
       [0.68004614, 0.55878718],
       [0.65412882, 0.53776177],
       [0.6880832 , 0.3147122 ],
       [0.74227919, 0.59824516],
       [0.66256439, 0.54326111]]

# %%
# 4 Clusters - preparation
# pca_dims = 10, N_samples = 35
acc = [[0.77272727, 0.59090909],
       [0.77272727, 0.54545455],
       [0.72727273, 0.54545455],
       [0.72727273, 0.77272727],
       [0.86363636, 0.81818182],
       [0.63636364, 0.63636364],
       [0.72727273, 0.54545455],
       [0.77272727, 0.68181818],
       [0.77272727, 0.59090909],
       [0.77272727, 0.63636364]]

# pca_dims = 20, N_samples = 35
acc = [[0.77272727, 0.59090909],
       [0.68181818, 0.59090909],
       [0.86363636, 0.63636364],
       [0.68181818, 0.40909091],
       [0.77272727, 0.54545455],
       [0.77272727, 0.81818182],
       [0.72727273, 0.68181818],
       [0.81818182, 0.72727273],
       [0.72727273, 0.68181818],
       [0.77272727, 0.68181818]]
